# %%
pip install requests beautifulsoup4 reportlab
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\computer market\appdata\roaming\python\python313\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\computer market\appdata\roaming\python\python313\site-packages (4.14.3)
# Collecting reportlab
#   Using cached reportlab-4.4.10-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\computer market\appdata\roaming\python\python313\site-packages (from reportlab) (12.0.0)
# Using cached reportlab-4.4.10-py3-none-any.whl (2.0 MB)
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.10
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet

# %%
url = "https://chaldal.com/fresh-vegetable"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

products = []

# NOTE: 
for item in soup.find_all("div"):
    name = item.find("p")
    price = item.find("span")

    if name and price:
        products.append((name.text.strip(), price.text.strip()))

# Create PDF
doc = SimpleDocTemplate("vegetables.pdf")
styles = getSampleStyleSheet()

elements = []

for name, price in products:
    text = f"{name} - {price}"
    elements.append(Paragraph(text, styles["Normal"]))
    elements.append(Spacer(1, 10))

doc.build(elements)

print("PDF generated: vegetables.pdf")
# Out:
# PDF generated: vegetables.pdf
